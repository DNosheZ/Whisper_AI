# %% [markdown]
# <a href="https://colab.research.google.com/github/DNosheZ/Whisper_AI/blob/main/Whisper_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Asignar GPU para ejecucion

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-f57be6f9-4179-d79e-aad2-05f1b1419fc0)

# %% [markdown]
# Obtenemos acceso a Drive para extraer los audios/videos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Instalando whisper

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-b4er3inj
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-b4er3inj
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
import whisper

# %% [markdown]
# Asignando un modelo de transcripcion, de los siguientes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model=whisper.load_model('large')
# Out:
# 100%|██████████████████████████████████████| 2.88G/2.88G [00:28<00:00, 108MiB/s]

# %% [markdown]
# de aqui en adelante se esta empleando el modelo de whisper para transcribir

# %%
from ipywidgets import Video

video_path='/content/drive/MyDrive/Entrevista Mario Martinez-ACVC.m4a'
#Video.from_file(video_path,width=550,play=True)#con esta linea podemos reproducir el video en el path(opcional)

# %% [markdown]
# Y ahora, la magia

# %%
result=model.transcribe(video_path)
result['text']
# Out:
# ' Muy buenas tardes, nos encontramos hoy en el municipio de Cantagallo, en la vereda La Posa, en compañía de Mario Martínez Maecha. Mario, una feliz tarde, muchas gracias por tu tiempo y tu disposición para presentar esta entrevista que se hace en el marco de la maestría en Educación y Derechos Humanos, de la Universidad Autónoma Latinoamericana con sede en Medellín, y que tiene la intención entonces de analizar las subjetivaciones del campesinado en las zonas de reserva campesina de Tarazá y particularmente la del Valle del Río Cimitarra, identificando las experiencias emancipatorias en contextos de conflicto territorial y de subalternidad en el modo de producción capitalista. Como objetivos específicos de la investigación se tienen identificar las prácticas de agenciamiento que fortalecen la autonomía territorial y como segundo objetivo específico indagar por las subalternidades para reconocer los límites y alcances políticos de las zonas de reserva campesina. Mario, bienvenido. Mu
# ...
